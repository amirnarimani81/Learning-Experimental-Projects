# %% [markdown]
# <div style="font-family:Segoe UI, sans-serif; padding:20px;">
#
#    <!-- MAIN HEADER -->
#   <h1 style="
#         background: linear-gradient(to right, #ffffff, #1fa34a);
#         padding: 20px;
#         border-radius: 12px;
#         text-align: center;
#         font-size: 38px;
#         color: navy;">
#         🧪 Data Science & Web Scraping Portfolio
#     </h1>
#
#  <!-- BADGES -->
#   <p style="text-align:center;">
#         <img src="https://img.shields.io/badge/Python-3.10+-blue">
#         <img src="https://img.shields.io/badge/Web%20Scraping-BeautifulSoup-green">
#         <img src="https://img.shields.io/badge/Data-API / HTML-orange">
#         <img src="https://img.shields.io/badge/Automation-Scheduling-purple">
#         <img src="https://img.shields.io/badge/Visualization-Plotly-yellow">
#         <img src="https://img.shields.io/badge/Pandas-Data%20Cleaning-red">
#     </p>
#
#   <p style="font-size:16px; background:#f8fffa; padding:15px; border-left:5px solid green; border-radius:6px;">
#         This repository contains four real-world data engineering and web scraping projects.
#         These projects demonstrate my ability to extract, clean, analyze, and visualize data from
#         <strong>APIs, dynamic websites, and multi-page sources</strong>.
#     </p>
#
#   <!-- TABLE OF CONTENTS -->
#  <h2 style="color:#0a7;">📘 Table of Contents</h2>
#     <ul style="font-size:16px;">
#         <li><a href="#p1">Project 1 — Stock Data & Revenue Data Scraping (YFinance + Web Scraping)</a></li>
#         <li><a href="#p2">Project 2 — Amazon Product Price Web Scraper</a></li>
#         <li><a href="#p3">Project 3 — OpenCodez Multi-Page Blog Scraper</a></li>
#         <li><a href="#p4">Project 4 — Booking.com Hotel Scraper</a></li>
#         <li><a href="#skills">Skills Gained Across Projects</a></li>
#         <li><a href="#tech">Technologies Used</a></li>
#     </ul>
#
#
#  <!-- PROJECT 1 -->
# <h2 id="p1" style="color:#0077cc;">📈 Project 1 — Stock Data Extraction & Visualization</h2>
#
#   <div style="background:#eefaff; padding:15px; border-radius:8px;">
#         <p>
#             This project extracts historical stock data for <strong>Tesla (TSLA)</strong> and <strong>GameStop (GME)</strong> using
#             <strong>yfinance</strong> and revenue data using <strong>web scraping</strong>.
#         </p>
#     <ul>
#             <li>Downloaded historical share prices</li>
#             <li>Scraped revenue tables from Macrotrends</li>
#             <li>Cleaned inconsistent table data</li>
#             <li>Combined stock data + revenue visualizations</li>
#             <li>Created custom Plotly dual-subplot graphs</li>
#         </ul>
#
# <pre style="background:#1e1e1e; color:white; padding:10px; border-radius:8px;">
# data = yf.download("TSLA", start="2023-01-01", interval="1wk")
# soup = BeautifulSoup(response.text, "html.parser")
# tables = soup.find_all("table")
#         </pre>
# </div>
#
#
#  <!-- PROJECT 2 -->
#   <h2 id="p2" style="color:#d46d00;">🛒 Project 2 — Amazon Product Price Web Scraper</h2>
#
#  <div style="background:#fff7ed; padding:15px; border-radius:8px;">
#         <p>
#             A fully automated scraper that collects product details from Amazon:
#         </p>
#         <ul>
#             <li>Product title</li>
#             <li>Price</li>
#             <li>Rating</li>
#             <li>Review count</li>
#             <li>Product link</li>
#         </ul>
#
#   <p>Useful for competitor analysis, price tracking, and product research.</p>
#
#  <pre style="background:#1e1e1e; color:white; padding:10px; border-radius:8px;">
# title = soup.find("span", id="productTitle").get_text().strip()
# price = soup.find("span", class_="a-price-whole").get_text()
#         </pre>
#  </div>
#
#
#  <!-- PROJECT 3 -->
#  <h2 id="p3" style="color:#8b00ff;">📰 Project 3 — OpenCodez Blog Scraper (Multi-Page)</h2>
#
#  <div style="background:#f7ecff; padding:15px; border-radius:8px;">
#         <p>
#             Scrapes all blog posts across multiple pages from <strong>OpenCodez</strong> using advanced BeautifulSoup selectors.
#         </p>
#
#   <ul>
#             <li>Extracts Titles, Descriptions, Authors</li>
#             <li>Handles Month-Day and Year formatting</li>
#             <li>Captures post image links + article URLs</li>
#             <li>Validates HTML structure to avoid data mismatch</li>
#             <li>Exports a clean Pandas DataFrame</li>
#         </ul>
#
#
#  <!-- PROJECT 4 -->
#   <h2 id="p4" style="color:#009966;">🏨 Project 4 — Booking.com Hotel Scraper</h2>
#
#  <div style="background:#e9fff5; padding:15px; border-radius:8px;">
#         <p>
#             A robust web scraping tool for extracting hotel listings from <strong>Booking.com</strong>.
#             This scraper collects:
#         </p>
#
#  <ul>
#             <li>Hotel Name</li>
#             <li>Location</li>
#             <li>Price</li>
#             <li>Rating & Review Count</li>
#             <li>Direct Booking Link</li>
#         </ul>
#
#  <p>
#             Includes header rotation, error handling, anti-blocking strategies, and CSV output.
#         </p>
#
#   <pre style="background:#1e1e1e; color:white; padding:10px; border-radius:8px;">
# page = requests.get(URL, headers=headers)
# name = h.find("div", {"data-testid": "title"}).text
# price = h.find("span", {"data-testid": "price-and-discounted-price"}).text
#         </pre>
#   </div>
#
#
#
# <!-- SKILLS -->
#   <h2 id="skills" style="color:#0a7;">💡 Skills Demonstrated Across These Projects</h2>
#     <ul style="font-size:16px;">
#         <li>Python Web Scraping (BeautifulSoup, Requests)</li>
#         <li>API Data Extraction (YFinance)</li>
#         <li>Data Cleaning & Transformation (Pandas)</li>
#         <li>HTML Parsing & Tag Selection</li>
#         <li>Multi-Page Scraping Techniques</li>
#         <li>Error Handling & Anti-Blocking Techniques</li>
#         <li>CSV/Excel Reporting</li>
#         <li>Interactive Data Visualization (Plotly)</li>
#         <li>Building Modular Reusable Code</li>
#         <li>Automation & Scheduling</li>
#     </ul>
#
#
#  <!-- TECH STACK -->
#  <h2 id="tech" style="color:#066;">🛠️ Technologies Used</h2>
#
#  <ul style="font-size:16px;">
#         <li><strong>Python 3.x</strong></li>
#         <li><strong>BeautifulSoup4</strong></li>
#         <li><strong>Requests</strong></li>
#         <li><strong>Pandas</strong></li>
#         <li><strong>YFinance API</strong></li>
#         <li><strong>Plotly / Matplotlib</strong></li>
#         <li><strong>Jupyter Notebook</strong></li>
#     </ul>
#
# <h2 style="text-align:center; color:green;">
#         🚀 This portfolio demonstrates complete end-to-end scraping, cleaning, and analysis workflows.
#     </h2>
#
# </div>
